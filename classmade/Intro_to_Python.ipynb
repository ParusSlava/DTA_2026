# %% [markdown]
# <a href="https://colab.research.google.com/github/ParusSlava/DTA_2026/blob/main/classmade/Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world! I am the best")
# Out:
# Hello world! I am the best

# %%
age = 25

# %%
print(25)
# Out:
# 25

# %%
is_young = True

# %%
type(is_young)
# Out:
# bool

# %%
age = input("How old are you?")
# Out:
# How old are you25

# %%
age = int(input("How old are you?"))
# Out:
# How old are you?25

# %%
grade = 85

# %%
grade = 85

if grade >=90:
  print("Відмінно")
elif grade >= 75:
  print("Добре")
elif grade >= 60:
  print("Задовільно")
else:
  print("Не склав")
# Out:
# Добре

# %%
for i in range(1, 6):
  print("Я отримав такий бал -", i)
# Out:
# Я отримав такий бал - 1
# Я отримав такий бал - 2
# Я отримав такий бал - 3
# Я отримав такий бал - 4
# Я отримав такий бал - 5

# %%
name = input("What is your name?")

grade1 = int(input("What is your first grade?"))
grade2 = int(input("What is your second grade?"))
grade3 = int(input("What is your third grade?"))

average = (grade1 + grade2 + grade3)/3

print("Hello", name, ". Nice to meet you!")
print("Your average grade is:", average)

if average >= 60:
  print("Congratulations, you passed!")
else:
  print("Sorry, you need to retake the exam.")
# Out:
# What is your name?Iaroslava
# What is your first grade?50
# What is your second grade?60
# What is your third grade?70
# Hello Iaroslava . Nice to meet you!
# Your average grade is: 60.0
# Congratulations, you passed!
