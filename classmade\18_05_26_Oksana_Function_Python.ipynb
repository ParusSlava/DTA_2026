# %% [markdown]
# <a href="https://colab.research.google.com/github/ParusSlava/DTA_2026/blob/main/classmade%5C18_05_26_Oksana_Function_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function Python
#
# ```
# def name_func():
#   pass
# ```
